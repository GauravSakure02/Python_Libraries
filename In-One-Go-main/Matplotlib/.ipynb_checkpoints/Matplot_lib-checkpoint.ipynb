# %%
import matplotlib.pyplot as plt
import matplotlib as mp
import numpy as np

# %matplotlib inline

# %%
x = np.linspace(0,4*np.pi,100)
sin_y = np.sin(x)
cos_y = np.cos(x)
plt.plot(x,sin_y,label="sine")
plt.plot(x,cos_y,label="cosine")
plt.legend(loc="upper right")
plt.title("sine wave")
plt.show()

# %%
plt.plot(x, sin_y,  '*')
plt.plot(x, cos_y,  '--')

plt.title('Sine Wave')

plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-dark')
plt.plot(x,sin_y,label="sine")
plt.plot(x,cos_y,label="cosine")
plt.title("Sine & Cosine Wave")
plt.legend()
plt.show()
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_18300\3646485019.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-dark')

# %%
plt.figure(figsize = (18,5))

plt.style.use('seaborn-dark')

plt.plot(x, sin_y,label = 'Sine')
plt.plot(x, cos_y,label = 'Cosine')

plt.title('Sine & Cosine Wave')
fig = plt.figure()
fig.savefig("Sine_Cosine.png")
plt.legend()
plt.show()
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_18300\4240687458.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-dark')
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from IPython.display import Image

Image('Sine & Cosine.png')

# %%
x = np.linspace(0,4*np.pi,100)
y = np.sin(x)
plt.style.use('Solarize_Light2')
plt.plot(x,y)
plt.title('Sine & Cosine Wave')
plt.show()

# %%
x = np.linspace(0,4*np.pi, 100)

y_sin = np.sin(x)
y_cos = np.cos(x)

plt.figure(figsize = (9,9))
plt.style.use('Solarize_Light2')

plt.plot(x, y_sin,  '-' ,color = 'pink' , linewidth = 1, label = 'sin')
plt.plot(x, y_cos, '*' , color = 'red', linewidth = 1, label = 'cos')

plt.title('Sine & Cosine Wave')
plt.legend()
plt.show()

# %%
x = np.linspace(0, 4*np.pi, 100)
plt.xlim(0,10)
plt.ylim(-2.5,2.5)
sin_y = np.sin(x)
plt.plot(x,sin_y)
plt.title("Sine Wave")
plt.show()

# %%
x = np.linspace(0,4*np.pi,100)
plt.xlim([0,10])
plt.ylim([-2.5,2.5])
sin_y = np.sin(x)
plt.plot(x,sin_y)
plt.title("Sine Wave")
plt.show()

# %%
x = np.linspace(0,4*np.pi,100)
fig = plt.axes()
plt.plot(x,np.sin(x))
fig.set(xlim=(0,10),ylim=(-2,2),xlabel="x",ylabel="sin(x)",title="Sine Wave")
plt.plot()
# Out:
# []

# %%
n = 500
x = np.random.randn(n)
y = np.random.randn(n)

plt.scatter(x,y,c="orange",alpha=.8,s=30)
plt.plot()
plt.show()

# %%
n =1000
x1 = np.random.randn(n)
y1 = np.random.randn(n)
x2 = np.random.randn(n) + 2
y2 = np.random.randn(n) + 2
plt.scatter(x1,y1,c="red",alpha=.7,s=10,label='group-1')
plt.scatter(x2,y2,c="blue",alpha=.7,s=10,label='group-2')
plt.title("Scatter plot with multiple groups")
plt.plot()
plt.show()

# %%
from sklearn.datasets import load_iris
iris = load_iris()
x = iris.data
y = iris.target
plt.scatter(x[:,2],x[:,3],c="lightgreen",s=50,alpha=.9,marker='^')
plt.title("iris")
plt.xlabel(iris['feature_names'][2])
plt.ylabel(iris['feature_names'][3])
plt.show()

# %%
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)

colors = rng.rand(100)
sizes  = rng.rand(100) * 1000

plt.scatter(x,y, c = colors, s = sizes , alpha = .7, cmap = 'viridis', edgecolors = 'black')

plt.title('Random Scatter Plot')
plt.xlabel('x values')
plt.ylabel('y values')

plt.colorbar()

plt.show()

# %%
iris = load_iris()
feature = iris.data
plt.scatter(feature[:,0],feature[:,1],alpha =.8,cmap='viridis',s=feature[:,3]*100,c=iris.target)
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.colorbar()
plt.show()

# %%
data = np.random.randn(1000)

plt.hist(data)

plt.show()

# %%
data = np.random.randn(10000000)
plt.hist(data,bins=2000,edgecolor='red',alpha=.8,color='blue')
plt.title("Random Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %%
data = np.random.randn(10000000)
plt.hist(data,bins=20,edgecolor='Black',color='Red',alpha=.8,histtype='stepfilled')
plt.title("Random Histogram")
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
x1 = np.random.randn(1000)
x2 = np.random.randn(1000) + 2
x3 = np.random.randn(1000) + 4

plt.hist(x1,bins=20,alpha=.8)
plt.hist(x2,bins=20,alpha=.8)
plt.hist(x3,bins=20,alpha=.8)
plt.title("Random Experiment")
#plt.colorbar()
plt.show()

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.hist2d(x,y,cmap='viridis',alpha=.8,bins=20)
plt.title('2D Histogram')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.colorbar()
plt.show()

# %%
plt.hist2d(x,y, bins = 20 , cmap = 'Blues')
plt.title('2D Histogram')
plt.ylabel('x')
plt.xlabel('y')
plt.colorbar()

plt.show()

# %%
cars = ['AUDI','BMW','FORD','TESLA','JAGUAR','MERCEDES']
data = [ 450  , 385 , 35   ,   10  ,  200   , 500      ]
fig = plt.figure(figsize=(7,7))
plt.pie(data,labels=cars,autopct='%.2f')
plt.show()

# %%
cars = ['AUDI','BMW','FORD','TESLA','JAGUAR','MERCEDES']
data = [ 450  , 385 , 35   ,   10  ,  200   , 500      ]
explode = [.1, .1, .1 , .1, .1, .1] 

fig = plt.figure(figsize = (7,7))

plt.pie(data, labels = cars, explode = explode)

plt.show()

# %%
cars = ['AUDI','BMW','FORD','TESLA','JAGUAR','MERCEDES']
data = [ 450  , 385 , 35   ,   10  ,  200   , 500      ]
explode = [0, 0, 0 , 0, .1, 0] 

fig = plt.figure(figsize = (7,7))

plt.pie(data, labels = cars, explode = explode, shadow = True)

plt.show()

# %%
cars = ['AUDI','BMW','FORD','TESLA','JAGUAR','MERCEDES']
data = [ 450  , 385 , 35   ,   50  ,  200   , 500      ]
explode = [0, 0, 0 , 0, .1, 0] 

fig = plt.figure(figsize = (7,7))

plt.pie(data, labels = cars, explode = explode, shadow = True, autopct = '%2.2f%%')

plt.show()

# %%
fig = plt.figure(figsize = (7,7))

plt.pie(data, labels = cars, explode = explode, shadow = True, autopct = '%2.2f%%',
        wedgeprops = {'edgecolor' : 'black', 'linewidth' : 3, 'antialiased' : True})

plt.show()

# %%
x = np.linspace(0,10,50)

fig, ax = plt.subplots(2,2)

y = np.sin(x)
ax[0,0].plot(x,y)
ax[0,0].set_title('Sin Wave')


y = np.cos(x)
ax[0,1].plot(x,y)
ax[0,1].set_title('Cos Wave')

y = np.tan(x)
ax[1,0].plot(x,y)
ax[1,0].set_title('Tan Wave')


y = np.random.randn(1000)
ax[1,1].hist(y,bins = 40)
ax[1,1].set_title('Random Distribution')


plt.tight_layout()
plt.show()

# %%
plt.subplots_adjust(hspace = .4, wspace = .4)

for i in range(1,7):
    
    plt.subplot(2,3,i)
    plt.text(0.5 , 0.5, str((2,3,i)), fontsize = 18, ha = 'center')

# %%
x = np.linspace(0,10,50)
y = np.sin(x)


fig , (ax1,ax2,ax3) = plt.subplots(1,3, figsize = (18,6))
ax1.plot(x,y)
ax2.plot(x,y**2)
ax3.plot(x,y**3)

ax1.set_title('Sin Wave')
ax2.set_title('Sin Wave - Square')
ax3.set_title('Sin Wave - Cube')

plt.tight_layout()

plt.show()

# %%
plt.axes(projection='3d')
# Out:
# <Axes3D: >

# %%
ax = plt.axes(projection='3d')
z = np.linspace(0,15,100)
x = np.sin(z)
y = np.cos(z)

ax.plot3D(x,y,z,'blue')

# %%
from mpl_toolkits.mplot3d import Axes3D

fig  = plt.figure()
ax   = fig.add_subplot(111, projection = '3d')

x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

ax.scatter(x,y,z, c = 'BLACK', marker = '*')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.tight_layout()

plt.show()
